# %%
#1.The following code throws an error. What is wrong?
import tensorflow as tf
model = keras.Sequential()  # Error here

#Ans:NameError keras is not defined.

# %%
#2.
from sklearn.svm import SVC
from sklearn.datasets import load_diabetes

X, y = load_diabetes(return_X_y=True)

model = SVC()
model.fit(X, y)  # Error

#ans:X and y not split from the dataset

# %%
#3.
from sklearn.tree import RandomForestClassifier  # Incorrect import
clf = RandomForestClassifier()
# ans: sklearn.tree used for import DecisionTree not for import RandomForestClassifier

# %%
#4.
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X = [[1, 2], [3, 4], [5, 6], [7, 8]]
y = [0, 1, 0, 1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)  # Error
#Ans:X_test can't be used for training.X_test only used for evaluating the model performance.

# %%
#5.
import pandas as pd
df = pd.DataFrame({'age': [25, 30, 35], 'salary': [50000, 60000, 70000]})
print(df['salry'])  # Typo
# Ans:it is Type error.the line should be print(df['salary'])

# %%
#6.
import pandas as pd
df = pd.DataFrame({'Age': ['25', '30', '35']})  # Stored as string
print(df['Age'].mean())
#Ans:String can't be used for computing mean.so the code  should be
# df = pd.DataFrame({'Age': [25, 30, 35]})  it stores as integer.Now it is used for computing mean

# %%
#7.
def add_numbers(a, b):
result = a + b
 return result

#Ans: The error is spacing.The code should be
'''def add_numbers(a, b):
      result = a + b
      return result'''

# %%
#8.
from sklearn.model_selection import train_test_split
X = [1, 2, 3, 4, 5]
y = [1, 0, 1, 0]  # Mismatched length
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# ans:Mismatched length in y
# y=[1,0,1,0,1]

# %%
#9.
print(my_name)
my_name = "Alice"
# ans:Name error:my_name is not defined
'''
correted code:
my_name="Alice"
print(my_name) '''

# %%
#10.
import pandas as pd

df = pd.DataFrame({'Age': [25, 30, 35, 40]})
df['Age_Category'] = df['Age'].apply(lambda x: 'Young' if x < 30 'Old')  # Error

# Ans:Condition should be given in outside
